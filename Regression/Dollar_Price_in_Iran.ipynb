# %% [markdown]
# # Dollar price per Toman

# %%
import pandas as pd
import numpy as np
import sklearn.linear_model
import sklearn.metrics
import sklearn.preprocessing
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as py

# %% [markdown]
# ## Loading Data

# %%
df = pd.read_csv('Dollar_Rial_Price_Dataset.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3719 entries, 0 to 3718
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Open Price      3719 non-null   int64
#  1   Low Price       3719 non-null   int64
#  2   High Price      3719 non-null   int64
#  3   Close Price     3719 non-null   int64
#  4   Change Amount   3719 non-null   object
#  5   Change Percent  3719 non-null   object
#  6   Gregorian Date  3719 non-null   object
#  7   Persian Date    3719 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 232.6+ KB

# %%
df.head()
# Out:
#    Open Price  Low Price  High Price  Close Price Change Amount  \
# 0     1159700    1159300     1174200      1173800         15200
# 1     1140000    1139800     1158700      1158600         16900
# 2     1136150    1135800     1144200      1141700          5300
# 3     1134500    1131800     1139200      1136400          1800
# 4     1133150    1127800     1138200      1134600          3000
#
#   Change Percent Gregorian Date Persian Date
# 0          1.31%     2025/11/30   1404/09/09
# 1          1.48%     2025/11/29   1404/09/08
# 2          0.47%     2025/11/27   1404/09/06
# 3          0.16%     2025/11/26   1404/09/05
# 4          0.26%     2025/11/25   1404/09/04

# %%
df.dtypes
# Out:
# Open Price         int64
# Low Price          int64
# High Price         int64
# Close Price        int64
# Change Amount     object
# Change Percent    object
# Gregorian Date    object
# Persian Date      object
# dtype: object

# %% [markdown]
# #### Change the DataTypes

# %%
df["Change Amount"] = pd.to_numeric(df["Change Amount"], errors='coerce')


df.dtypes
# Out:
# Open Price          int64
# Low Price           int64
# High Price          int64
# Close Price         int64
# Change Amount     float64
# Change Percent     object
# Gregorian Date     object
# Persian Date       object
# dtype: object

# %%
df["Persian Date"] = pd.to_datetime(df["Persian Date"])

# %%
# !pip install jdatetime
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jdatetime in c:\users\arya\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (5.0.0)
# Requirement already satisfied: jalali-core>=1.0 in c:\users\arya\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jdatetime) (1.0.0)
